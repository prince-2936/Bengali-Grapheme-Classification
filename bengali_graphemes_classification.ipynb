# %%
# Colab library to upload files to notebook
from google.colab import files
 
# Install Kaggle library
# !pip install -q kaggle

# %%
# Upload kaggle API key file
uploaded = files.upload() #here
# Out:
#      <input type="file" id="files-1b9b5fe3-8de0-4eca-920f-29132c23e3de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b9b5fe3-8de0-4eca-920f-29132c23e3de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !ls -l ~/.kaggle
# Out:
# ls: cannot access '/root/.kaggle': No such file or directory

# %%
# !rm -rf ~/.kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !kaggle competitions download -c bengaliai-cv19
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading test.csv to /content
#   0% 0.00/1.70k [00:00<?, ?B/s]
# 100% 1.70k/1.70k [00:00<00:00, 4.50MB/s]
# Downloading train_image_data_1.parquet.zip to /content
#  98% 969M/986M [00:24<00:00, 39.3MB/s]
# 100% 986M/986M [00:24<00:00, 42.1MB/s]
# Downloading test_image_data_0.parquet.zip to /content
#   0% 0.00/1.18M [00:00<?, ?B/s]
# 100% 1.18M/1.18M [00:00<00:00, 169MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/944 [00:00<?, ?B/s]
# 100% 944/944 [00:00<00:00, 941kB/s]
# Downloading train.csv.zip to /content
#   0% 0.00/1.32M [00:00<?, ?B/s]
# 100% 1.32M/1.32M [00:00<00:00, 88.3MB/s]
# Downloading test_image_data_2.parquet.zip to /content
#   0% 0.00/1.25M [00:00<?, ?B/s]
# 100% 1.25M/1.25M [00:00<00:00, 81.2MB/s]
# Downloading train_image_data_3.parquet.zip to /content
# 100% 989M/993M [00:22<00:00, 52.8MB/s]
# 100% 993M/993M [00:22<00:00, 45.7MB/s]
# Downloading class_map.csv to /content
#   0% 0.00/4.72k [00:00<?, ?B/s]
# 100% 4.72k/4.72k [00:00<00:00, 4.91MB/s]
# Downloading train_image_data_2.parquet.zip to /content
# 100% 992M/992M [00:20<00:00, 45.0MB/s]
#
# Downloading test_image_data_3.parquet.zip to /content
#   0% 0.00/1.28M [00:00<?, ?B/s]
# 100% 1.28M/1.28M [00:00<00:00, 181MB/s]
# Downloading test_image_data_1.parquet.zip to /content
#   0% 0.00/1.30M [00:00<?, ?B/s]
# 100% 1.30M/1.30M [00:00<00:00, 188MB/s]
# Downloading train_image_data_0.parquet.zip to /content
#  99% 985M/991M [00:22<00:00, 34.1MB/s]
# 100% 991M/991M [00:22<00:00, 45.9MB/s]
# Downloading class_map_corrected.csv to /content
#   0% 0.00/4.75k [00:00<?, ?B/s]
# 100% 4.75k/4.75k [00:00<00:00, 4.33MB/s]
# Downloading train_multi_diacritics.csv to /content
#   0% 0.00/16.8k [00:00<?, ?B/s]
# 100% 16.8k/16.8k [00:00<00:00, 17.6MB/s]

# %%
# !kaggle datasets download -d kaushal2896/kalpurush-fonts
# Out:
# Downloading kalpurush-fonts.zip to /content
#   0% 0.00/155k [00:00<?, ?B/s]
# 100% 155k/155k [00:00<00:00, 49.0MB/s]

# %%
# !unzip kalpurush-fonts.zip
# Out:
# Archive:  kalpurush-fonts.zip
#   inflating: kalpurush-2.ttf

# %%
# !unzip /content/test_image_data_0.parquet.zip 
# !unzip /content/test_image_data_1.parquet.zip 
# !unzip /content/test_image_data_2.parquet.zip 
# !unzip /content/test_image_data_3.parquet.zip 

# !unzip /content/train_image_data_0.parquet.zip
# !unzip /content/train_image_data_1.parquet.zip
# !unzip /content/train_image_data_2.parquet.zip
# !unzip /content/train_image_data_3.parquet.zip
# Out:
# Archive:  /content/test_image_data_0.parquet.zip
#   inflating: test_image_data_0.parquet
# Archive:  /content/test_image_data_1.parquet.zip
#   inflating: test_image_data_1.parquet
# Archive:  /content/test_image_data_2.parquet.zip
#   inflating: test_image_data_2.parquet
# Archive:  /content/test_image_data_3.parquet.zip
#   inflating: test_image_data_3.parquet
# Archive:  /content/train_image_data_0.parquet.zip
#   inflating: train_image_data_0.parquet
# Archive:  /content/train_image_data_1.parquet.zip
#   inflating: train_image_data_1.parquet
# Archive:  /content/train_image_data_2.parquet.zip
#   inflating: train_image_data_2.parquet
# Archive:  /content/train_image_data_3.parquet.zip
#   inflating: train_image_data_3.parquet

# %%
# !unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
# !ls
# Out:
# class_map_corrected.csv        test_image_data_3.parquet
# class_map.csv		       test_image_data_3.parquet.zip
# kaggle.json		       train.csv
# kalpurush-2.ttf		       train.csv.zip
# kalpurush-fonts.zip	       train_image_data_0.parquet
# sample_data		       train_image_data_0.parquet.zip
# sample_submission.csv	       train_image_data_1.parquet
# test.csv		       train_image_data_1.parquet.zip
# test_image_data_0.parquet      train_image_data_2.parquet
# test_image_data_0.parquet.zip  train_image_data_2.parquet.zip
# test_image_data_1.parquet      train_image_data_3.parquet
# test_image_data_1.parquet.zip  train_image_data_3.parquet.zip
# test_image_data_2.parquet      train_multi_diacritics.csv
# test_image_data_2.parquet.zip

# %%
import os
os.getcwd ()
# Out:
# '/content'

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /content/test.csv
# /content/train_image_data_2.parquet
# /content/train_multi_diacritics.csv
# /content/class_map_corrected.csv
# /content/train.csv.zip
# /content/train_image_data_1.parquet.zip
# /content/test_image_data_0.parquet
# /content/train_image_data_0.parquet.zip
# /content/test_image_data_3.parquet
# /content/test_image_data_0.parquet.zip
# /content/train.csv
# /content/train_image_data_3.parquet
# /content/test_image_data_1.parquet.zip
# /content/kaggle.json
# /content/test_image_data_3.parquet.zip
# /content/kalpurush-2.ttf
# /content/train_image_data_2.parquet.zip
# /content/sample_submission.csv
# /content/train_image_data_3.parquet.zip
# /content/train_image_data_1.parquet
# /content/test_image_data_1.parquet
# /content/test_image_data_2.parquet.zip
# /content/kalpurush-fonts.zip
# /content/class_map.csv
# /content/train_image_data_0.parquet
# /content/test_image_data_2.parquet
# /content/.config/active_config
# /content/.config/config_sentinel
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/.last_survey_prompt.yaml
# /content/.config/.last_update_check.json
# /content/.config/gce
# /content/.config/.metricsUUID
# /content/.config/logs/2020.10.05/16.30.42.685964.log
# /content/.config/logs/2020.10.05/16.31.17.532147.log
# /content/.config/logs/2020.10.05/16.30.57.046091.log
# /content/.config/logs/2020.10.05/16.31.02.426408.log
# /content/.config/logs/2020.10.05/16.30.24.482958.log
# /content/.config/logs/2020.10.05/16.31.18.233006.log
# /content/.config/configurations/config_default
# /content/sample_data/anscombe.json
# /content/sample_data/README.md
# /content/sample_data/california_housing_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/mnist_train_small.csv

# %%
train_df_ = pd.read_csv('/content/train.csv')
test_df_ = pd.read_csv('/content/test.csv')
class_map_df = pd.read_csv('/content/class_map.csv')
sample_sub_df = pd.read_csv('/content/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype('/content/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')

# %% [markdown]
# ### Least used 10 Grapheme Roots in training set

# %%
bottom_10_roots = get_n(train_df_, 'grapheme_root', 10, False)
bottom_10_roots
# Out:
#      index component  count
# 73      73       দ্ঘ    130
# 33      33     ঙ্ক্ত    136
# 102    102       প্স    141
# 158    158       স্স    143
# 45      45     জ্জ্ব    144
# 130    130       ল্ব    144
# 1        1         ঃ    145
# 12      12         ঔ    146
# 0        0         ং    147
# 63      63       ণ্ণ    149

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(bottom_10_roots['component'].iloc[i]), cmap='Greys')

# %% [markdown]
# ### Top 5 Vowel Diacritic in taining data

# %%
top_5_vowels = get_n(train_df_, 'vowel_diacritic', 5)
top_5_vowels
# Out:
#    index component  count
# 0    168         0  41508
# 1    169         া  36886
# 7    175         ে  28723
# 2    170         ি  25967
# 4    172         ু  18848

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_vowels['component'].iloc[i]), cmap='Greys')

# %% [markdown]
# ### Top 5 Consonant Diacritic in training data

# %%
top_5_consonants = get_n(train_df_, 'consonant_diacritic', 5)
top_5_consonants
# Out:
#    index component   count
# 0    179         0  125278
# 2    181        র্   23465
# 5    184        ্র   21397
# 4    183        ্য   21270
# 1    180         ঁ    7424

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_consonants['component'].iloc[i]), cmap='Greys')

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# Let's apply some image processing (credits: [this kernel](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)) while resizing the images, which will center crop the region of interest from the original images.

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   102464      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 4, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         4195328     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          524800      dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 168)          86184       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 11)           5643        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 7)            3591        dense_1[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop

# %%
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
#don't run this cell during prediction

histories = []
for i in range(1):
    train_df = pd.merge(pd.read_parquet(f'/content/train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_2': y_train_root, 'dense_3': y_train_vowel, 'dense_4': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    model.save('bengali_model.h5')
    np.save('history.npy',history)
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50210.0), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# WARNING:tensorflow:From <ipython-input-46-c9377dac4889>:59: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:3350: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# Epoch 1/30
# 180/180 [==============================] - ETA: 0s - loss: 7.8205 - dense_2_loss: 4.7515 - dense_3_loss: 1.8811 - dense_4_loss: 1.1880 - dense_2_accuracy: 0.0295 - dense_3_accuracy: 0.3298 - dense_4_accuracy: 0.6219WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 228ms/step - loss: 7.8205 - dense_2_loss: 4.7515 - dense_3_loss: 1.8811 - dense_4_loss: 1.1880 - dense_2_accuracy: 0.0295 - dense_3_accuracy: 0.3298 - dense_4_accuracy: 0.6219 - val_loss: 6.7276 - val_dense_2_loss: 4.5503 - val_dense_3_loss: 1.1580 - val_dense_4_loss: 1.0193 - val_dense_2_accuracy: 0.0403 - val_dense_3_accuracy: 0.6184 - val_dense_4_accuracy: 0.6497
# Epoch 2/30
# 180/180 [==============================] - ETA: 0s - loss: 6.7088 - dense_2_loss: 4.4728 - dense_3_loss: 1.2344 - dense_4_loss: 1.0016 - dense_2_accuracy: 0.0454 - dense_3_accuracy: 0.5735 - dense_4_accuracy: 0.6551WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 6.7088 - dense_2_loss: 4.4728 - dense_3_loss: 1.2344 - dense_4_loss: 1.0016 - dense_2_accuracy: 0.0454 - dense_3_accuracy: 0.5735 - dense_4_accuracy: 0.6551 - val_loss: 6.0853 - val_dense_2_loss: 4.2575 - val_dense_3_loss: 0.9359 - val_dense_4_loss: 0.8919 - val_dense_2_accuracy: 0.0595 - val_dense_3_accuracy: 0.6647 - val_dense_4_accuracy: 0.6741
# Epoch 3/30
# 180/180 [==============================] - ETA: 0s - loss: 5.9310 - dense_2_loss: 4.1026 - dense_3_loss: 0.9803 - dense_4_loss: 0.8481 - dense_2_accuracy: 0.0736 - dense_3_accuracy: 0.6683 - dense_4_accuracy: 0.7046WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 5.9310 - dense_2_loss: 4.1026 - dense_3_loss: 0.9803 - dense_4_loss: 0.8481 - dense_2_accuracy: 0.0736 - dense_3_accuracy: 0.6683 - dense_4_accuracy: 0.7046 - val_loss: 4.8208 - val_dense_2_loss: 3.6019 - val_dense_3_loss: 0.5860 - val_dense_4_loss: 0.6329 - val_dense_2_accuracy: 0.1195 - val_dense_3_accuracy: 0.8133 - val_dense_4_accuracy: 0.7819
# Epoch 4/30
# 180/180 [==============================] - ETA: 0s - loss: 4.9826 - dense_2_loss: 3.5254 - dense_3_loss: 0.7853 - dense_4_loss: 0.6718 - dense_2_accuracy: 0.1381 - dense_3_accuracy: 0.7425 - dense_4_accuracy: 0.7637WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 4.9826 - dense_2_loss: 3.5254 - dense_3_loss: 0.7853 - dense_4_loss: 0.6718 - dense_2_accuracy: 0.1381 - dense_3_accuracy: 0.7425 - dense_4_accuracy: 0.7637 - val_loss: 3.6409 - val_dense_2_loss: 2.7665 - val_dense_3_loss: 0.4306 - val_dense_4_loss: 0.4439 - val_dense_2_accuracy: 0.2522 - val_dense_3_accuracy: 0.8593 - val_dense_4_accuracy: 0.8489
# Epoch 5/30
# 180/180 [==============================] - ETA: 0s - loss: 4.0006 - dense_2_loss: 2.8119 - dense_3_loss: 0.6658 - dense_4_loss: 0.5229 - dense_2_accuracy: 0.2507 - dense_3_accuracy: 0.7838 - dense_4_accuracy: 0.8221WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 40s 225ms/step - loss: 4.0006 - dense_2_loss: 2.8119 - dense_3_loss: 0.6658 - dense_4_loss: 0.5229 - dense_2_accuracy: 0.2507 - dense_3_accuracy: 0.7838 - dense_4_accuracy: 0.8221 - val_loss: 2.8016 - val_dense_2_loss: 2.0634 - val_dense_3_loss: 0.3581 - val_dense_4_loss: 0.3801 - val_dense_2_accuracy: 0.4197 - val_dense_3_accuracy: 0.8808 - val_dense_4_accuracy: 0.8626
# Epoch 6/30
# 180/180 [==============================] - ETA: 0s - loss: 3.1975 - dense_2_loss: 2.2046 - dense_3_loss: 0.5707 - dense_4_loss: 0.4222 - dense_2_accuracy: 0.3827 - dense_3_accuracy: 0.8184 - dense_4_accuracy: 0.8610WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 3.1975 - dense_2_loss: 2.2046 - dense_3_loss: 0.5707 - dense_4_loss: 0.4222 - dense_2_accuracy: 0.3827 - dense_3_accuracy: 0.8184 - dense_4_accuracy: 0.8610 - val_loss: 2.1381 - val_dense_2_loss: 1.5584 - val_dense_3_loss: 0.3022 - val_dense_4_loss: 0.2776 - val_dense_2_accuracy: 0.5360 - val_dense_3_accuracy: 0.9037 - val_dense_4_accuracy: 0.9047
# Epoch 7/30
# 180/180 [==============================] - ETA: 0s - loss: 2.6920 - dense_2_loss: 1.8181 - dense_3_loss: 0.4998 - dense_4_loss: 0.3741 - dense_2_accuracy: 0.4811 - dense_3_accuracy: 0.8402 - dense_4_accuracy: 0.8753WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 2.6920 - dense_2_loss: 1.8181 - dense_3_loss: 0.4998 - dense_4_loss: 0.3741 - dense_2_accuracy: 0.4811 - dense_3_accuracy: 0.8402 - dense_4_accuracy: 0.8753 - val_loss: 1.6628 - val_dense_2_loss: 1.1916 - val_dense_3_loss: 0.2347 - val_dense_4_loss: 0.2365 - val_dense_2_accuracy: 0.6520 - val_dense_3_accuracy: 0.9315 - val_dense_4_accuracy: 0.9253
# Epoch 8/30
# 180/180 [==============================] - ETA: 0s - loss: 2.2677 - dense_2_loss: 1.4997 - dense_3_loss: 0.4397 - dense_4_loss: 0.3283 - dense_2_accuracy: 0.5686 - dense_3_accuracy: 0.8626 - dense_4_accuracy: 0.8937WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 2.2677 - dense_2_loss: 1.4997 - dense_3_loss: 0.4397 - dense_4_loss: 0.3283 - dense_2_accuracy: 0.5686 - dense_3_accuracy: 0.8626 - dense_4_accuracy: 0.8937 - val_loss: 1.4519 - val_dense_2_loss: 0.9961 - val_dense_3_loss: 0.2323 - val_dense_4_loss: 0.2235 - val_dense_2_accuracy: 0.7137 - val_dense_3_accuracy: 0.9310 - val_dense_4_accuracy: 0.9313
# Epoch 9/30
# 180/180 [==============================] - ETA: 0s - loss: 1.9604 - dense_2_loss: 1.2661 - dense_3_loss: 0.3979 - dense_4_loss: 0.2964 - dense_2_accuracy: 0.6344 - dense_3_accuracy: 0.8753 - dense_4_accuracy: 0.9049WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 1.9604 - dense_2_loss: 1.2661 - dense_3_loss: 0.3979 - dense_4_loss: 0.2964 - dense_2_accuracy: 0.6344 - dense_3_accuracy: 0.8753 - dense_4_accuracy: 0.9049 - val_loss: 1.1994 - val_dense_2_loss: 0.8290 - val_dense_3_loss: 0.1994 - val_dense_4_loss: 0.1710 - val_dense_2_accuracy: 0.7613 - val_dense_3_accuracy: 0.9462 - val_dense_4_accuracy: 0.9450
# Epoch 10/30
# 180/180 [==============================] - ETA: 0s - loss: 1.8140 - dense_2_loss: 1.1477 - dense_3_loss: 0.3836 - dense_4_loss: 0.2827 - dense_2_accuracy: 0.6721 - dense_3_accuracy: 0.8804 - dense_4_accuracy: 0.9064WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 40s 225ms/step - loss: 1.8140 - dense_2_loss: 1.1477 - dense_3_loss: 0.3836 - dense_4_loss: 0.2827 - dense_2_accuracy: 0.6721 - dense_3_accuracy: 0.8804 - dense_4_accuracy: 0.9064 - val_loss: 1.0225 - val_dense_2_loss: 0.7217 - val_dense_3_loss: 0.1629 - val_dense_4_loss: 0.1380 - val_dense_2_accuracy: 0.7909 - val_dense_3_accuracy: 0.9539 - val_dense_4_accuracy: 0.9577
# Epoch 11/30
# 180/180 [==============================] - ETA: 0s - loss: 1.8841 - dense_2_loss: 1.1867 - dense_3_loss: 0.4028 - dense_4_loss: 0.2946 - dense_2_accuracy: 0.6685 - dense_3_accuracy: 0.8761 - dense_4_accuracy: 0.9050WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 1.8841 - dense_2_loss: 1.1867 - dense_3_loss: 0.4028 - dense_4_loss: 0.2946 - dense_2_accuracy: 0.6685 - dense_3_accuracy: 0.8761 - dense_4_accuracy: 0.9050 - val_loss: 1.7298 - val_dense_2_loss: 1.1494 - val_dense_3_loss: 0.3407 - val_dense_4_loss: 0.2397 - val_dense_2_accuracy: 0.7600 - val_dense_3_accuracy: 0.9358 - val_dense_4_accuracy: 0.9410
# Epoch 12/30
# 180/180 [==============================] - ETA: 0s - loss: 1.5282 - dense_2_loss: 0.9500 - dense_3_loss: 0.3351 - dense_4_loss: 0.2431 - dense_2_accuracy: 0.7264 - dense_3_accuracy: 0.8966 - dense_4_accuracy: 0.9215WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 1.5282 - dense_2_loss: 0.9500 - dense_3_loss: 0.3351 - dense_4_loss: 0.2431 - dense_2_accuracy: 0.7264 - dense_3_accuracy: 0.8966 - dense_4_accuracy: 0.9215 - val_loss: 0.9228 - val_dense_2_loss: 0.6225 - val_dense_3_loss: 0.1525 - val_dense_4_loss: 0.1477 - val_dense_2_accuracy: 0.8213 - val_dense_3_accuracy: 0.9559 - val_dense_4_accuracy: 0.9512
# Epoch 13/30
# 180/180 [==============================] - ETA: 0s - loss: 1.3784 - dense_2_loss: 0.8375 - dense_3_loss: 0.3144 - dense_4_loss: 0.2265 - dense_2_accuracy: 0.7587 - dense_3_accuracy: 0.9046 - dense_4_accuracy: 0.9284WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 40s 225ms/step - loss: 1.3784 - dense_2_loss: 0.8375 - dense_3_loss: 0.3144 - dense_4_loss: 0.2265 - dense_2_accuracy: 0.7587 - dense_3_accuracy: 0.9046 - dense_4_accuracy: 0.9284 - val_loss: 1.0923 - val_dense_2_loss: 0.7304 - val_dense_3_loss: 0.2063 - val_dense_4_loss: 0.1555 - val_dense_2_accuracy: 0.8155 - val_dense_3_accuracy: 0.9460 - val_dense_4_accuracy: 0.9497
# Epoch 14/30
# 180/180 [==============================] - ETA: 0s - loss: 1.3531 - dense_2_loss: 0.8188 - dense_3_loss: 0.3082 - dense_4_loss: 0.2261 - dense_2_accuracy: 0.7664 - dense_3_accuracy: 0.9071 - dense_4_accuracy: 0.9280WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 1.3531 - dense_2_loss: 0.8188 - dense_3_loss: 0.3082 - dense_4_loss: 0.2261 - dense_2_accuracy: 0.7664 - dense_3_accuracy: 0.9071 - dense_4_accuracy: 0.9280 - val_loss: 1.5476 - val_dense_2_loss: 0.9788 - val_dense_3_loss: 0.2978 - val_dense_4_loss: 0.2710 - val_dense_2_accuracy: 0.7339 - val_dense_3_accuracy: 0.9057 - val_dense_4_accuracy: 0.9039
# Epoch 15/30
# 180/180 [==============================] - ETA: 0s - loss: 1.4075 - dense_2_loss: 0.8432 - dense_3_loss: 0.3261 - dense_4_loss: 0.2381 - dense_2_accuracy: 0.7592 - dense_3_accuracy: 0.8996 - dense_4_accuracy: 0.9229WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 1.4075 - dense_2_loss: 0.8432 - dense_3_loss: 0.3261 - dense_4_loss: 0.2381 - dense_2_accuracy: 0.7592 - dense_3_accuracy: 0.8996 - dense_4_accuracy: 0.9229 - val_loss: 0.8934 - val_dense_2_loss: 0.6012 - val_dense_3_loss: 0.1605 - val_dense_4_loss: 0.1318 - val_dense_2_accuracy: 0.8364 - val_dense_3_accuracy: 0.9572 - val_dense_4_accuracy: 0.9614
# Epoch 16/30
# 180/180 [==============================] - ETA: 0s - loss: 1.6090 - dense_2_loss: 0.9497 - dense_3_loss: 0.3936 - dense_4_loss: 0.2657 - dense_2_accuracy: 0.7328 - dense_3_accuracy: 0.8765 - dense_4_accuracy: 0.9139
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 1.6090 - dense_2_loss: 0.9497 - dense_3_loss: 0.3936 - dense_4_loss: 0.2657 - dense_2_accuracy: 0.7328 - dense_3_accuracy: 0.8765 - dense_4_accuracy: 0.9139 - val_loss: 0.8819 - val_dense_2_loss: 0.5605 - val_dense_3_loss: 0.1771 - val_dense_4_loss: 0.1443 - val_dense_2_accuracy: 0.8389 - val_dense_3_accuracy: 0.9495 - val_dense_4_accuracy: 0.9562
# Epoch 17/30
# 180/180 [==============================] - ETA: 0s - loss: 1.1544 - dense_2_loss: 0.6702 - dense_3_loss: 0.2836 - dense_4_loss: 0.2006 - dense_2_accuracy: 0.8058 - dense_3_accuracy: 0.9126 - dense_4_accuracy: 0.9348WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 40s 225ms/step - loss: 1.1544 - dense_2_loss: 0.6702 - dense_3_loss: 0.2836 - dense_4_loss: 0.2006 - dense_2_accuracy: 0.8058 - dense_3_accuracy: 0.9126 - dense_4_accuracy: 0.9348 - val_loss: 0.6813 - val_dense_2_loss: 0.4257 - val_dense_3_loss: 0.1287 - val_dense_4_loss: 0.1269 - val_dense_2_accuracy: 0.8775 - val_dense_3_accuracy: 0.9617 - val_dense_4_accuracy: 0.9602
# Epoch 18/30
# 180/180 [==============================] - ETA: 0s - loss: 1.0875 - dense_2_loss: 0.6293 - dense_3_loss: 0.2710 - dense_4_loss: 0.1872 - dense_2_accuracy: 0.8181 - dense_3_accuracy: 0.9168 - dense_4_accuracy: 0.9403WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 227ms/step - loss: 1.0875 - dense_2_loss: 0.6293 - dense_3_loss: 0.2710 - dense_4_loss: 0.1872 - dense_2_accuracy: 0.8181 - dense_3_accuracy: 0.9168 - dense_4_accuracy: 0.9403 - val_loss: 0.6324 - val_dense_2_loss: 0.4179 - val_dense_3_loss: 0.1181 - val_dense_4_loss: 0.0964 - val_dense_2_accuracy: 0.8852 - val_dense_3_accuracy: 0.9689 - val_dense_4_accuracy: 0.9711
# Epoch 19/30
# 180/180 [==============================] - ETA: 0s - loss: 0.9730 - dense_2_loss: 0.5536 - dense_3_loss: 0.2471 - dense_4_loss: 0.1723 - dense_2_accuracy: 0.8380 - dense_3_accuracy: 0.9248 - dense_4_accuracy: 0.9444WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 0.9730 - dense_2_loss: 0.5536 - dense_3_loss: 0.2471 - dense_4_loss: 0.1723 - dense_2_accuracy: 0.8380 - dense_3_accuracy: 0.9248 - dense_4_accuracy: 0.9444 - val_loss: 0.6493 - val_dense_2_loss: 0.4357 - val_dense_3_loss: 0.1162 - val_dense_4_loss: 0.0974 - val_dense_2_accuracy: 0.8803 - val_dense_3_accuracy: 0.9669 - val_dense_4_accuracy: 0.9696
# Epoch 20/30
# 180/180 [==============================] - ETA: 0s - loss: 0.9205 - dense_2_loss: 0.5323 - dense_3_loss: 0.2277 - dense_4_loss: 0.1604 - dense_2_accuracy: 0.8448 - dense_3_accuracy: 0.9312 - dense_4_accuracy: 0.9489WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 0.9205 - dense_2_loss: 0.5323 - dense_3_loss: 0.2277 - dense_4_loss: 0.1604 - dense_2_accuracy: 0.8448 - dense_3_accuracy: 0.9312 - dense_4_accuracy: 0.9489 - val_loss: 0.7138 - val_dense_2_loss: 0.4540 - val_dense_3_loss: 0.1487 - val_dense_4_loss: 0.1111 - val_dense_2_accuracy: 0.8830 - val_dense_3_accuracy: 0.9614 - val_dense_4_accuracy: 0.9689
# Epoch 21/30
# 180/180 [==============================] - ETA: 0s - loss: 0.8614 - dense_2_loss: 0.4888 - dense_3_loss: 0.2216 - dense_4_loss: 0.1510 - dense_2_accuracy: 0.8537 - dense_3_accuracy: 0.9333 - dense_4_accuracy: 0.9521WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 40s 225ms/step - loss: 0.8614 - dense_2_loss: 0.4888 - dense_3_loss: 0.2216 - dense_4_loss: 0.1510 - dense_2_accuracy: 0.8537 - dense_3_accuracy: 0.9333 - dense_4_accuracy: 0.9521 - val_loss: 0.7081 - val_dense_2_loss: 0.4731 - val_dense_3_loss: 0.1296 - val_dense_4_loss: 0.1055 - val_dense_2_accuracy: 0.8788 - val_dense_3_accuracy: 0.9656 - val_dense_4_accuracy: 0.9679
# Epoch 22/30
# 180/180 [==============================] - ETA: 0s - loss: 0.8456 - dense_2_loss: 0.4823 - dense_3_loss: 0.2130 - dense_4_loss: 0.1503 - dense_2_accuracy: 0.8571 - dense_3_accuracy: 0.9351 - dense_4_accuracy: 0.9525WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 0.8456 - dense_2_loss: 0.4823 - dense_3_loss: 0.2130 - dense_4_loss: 0.1503 - dense_2_accuracy: 0.8571 - dense_3_accuracy: 0.9351 - dense_4_accuracy: 0.9525 - val_loss: 0.6134 - val_dense_2_loss: 0.3919 - val_dense_3_loss: 0.1238 - val_dense_4_loss: 0.0977 - val_dense_2_accuracy: 0.8927 - val_dense_3_accuracy: 0.9676 - val_dense_4_accuracy: 0.9681
# Epoch 23/30
# 180/180 [==============================] - ETA: 0s - loss: 0.8113 - dense_2_loss: 0.4583 - dense_3_loss: 0.2082 - dense_4_loss: 0.1449 - dense_2_accuracy: 0.8632 - dense_3_accuracy: 0.9385 - dense_4_accuracy: 0.9534WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 0.8113 - dense_2_loss: 0.4583 - dense_3_loss: 0.2082 - dense_4_loss: 0.1449 - dense_2_accuracy: 0.8632 - dense_3_accuracy: 0.9385 - dense_4_accuracy: 0.9534 - val_loss: 0.6065 - val_dense_2_loss: 0.3954 - val_dense_3_loss: 0.1168 - val_dense_4_loss: 0.0943 - val_dense_2_accuracy: 0.8900 - val_dense_3_accuracy: 0.9669 - val_dense_4_accuracy: 0.9711
# Epoch 24/30
# 180/180 [==============================] - ETA: 0s - loss: 0.7578 - dense_2_loss: 0.4301 - dense_3_loss: 0.1906 - dense_4_loss: 0.1371 - dense_2_accuracy: 0.8708 - dense_3_accuracy: 0.9419 - dense_4_accuracy: 0.9560WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 225ms/step - loss: 0.7578 - dense_2_loss: 0.4301 - dense_3_loss: 0.1906 - dense_4_loss: 0.1371 - dense_2_accuracy: 0.8708 - dense_3_accuracy: 0.9419 - dense_4_accuracy: 0.9560 - val_loss: 0.5592 - val_dense_2_loss: 0.3592 - val_dense_3_loss: 0.1060 - val_dense_4_loss: 0.0940 - val_dense_2_accuracy: 0.8994 - val_dense_3_accuracy: 0.9704 - val_dense_4_accuracy: 0.9711
# Epoch 25/30
# 180/180 [==============================] - ETA: 0s - loss: 0.7396 - dense_2_loss: 0.4167 - dense_3_loss: 0.1874 - dense_4_loss: 0.1355 - dense_2_accuracy: 0.8742 - dense_3_accuracy: 0.9434 - dense_4_accuracy: 0.9558WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 0.7396 - dense_2_loss: 0.4167 - dense_3_loss: 0.1874 - dense_4_loss: 0.1355 - dense_2_accuracy: 0.8742 - dense_3_accuracy: 0.9434 - dense_4_accuracy: 0.9558 - val_loss: 0.5940 - val_dense_2_loss: 0.3888 - val_dense_3_loss: 0.1051 - val_dense_4_loss: 0.1001 - val_dense_2_accuracy: 0.8967 - val_dense_3_accuracy: 0.9719 - val_dense_4_accuracy: 0.9686
# Epoch 26/30
# 180/180 [==============================] - ETA: 0s - loss: 0.7176 - dense_2_loss: 0.4018 - dense_3_loss: 0.1870 - dense_4_loss: 0.1288 - dense_2_accuracy: 0.8810 - dense_3_accuracy: 0.9437 - dense_4_accuracy: 0.9591WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 229ms/step - loss: 0.7176 - dense_2_loss: 0.4018 - dense_3_loss: 0.1870 - dense_4_loss: 0.1288 - dense_2_accuracy: 0.8810 - dense_3_accuracy: 0.9437 - dense_4_accuracy: 0.9591 - val_loss: 0.5994 - val_dense_2_loss: 0.3729 - val_dense_3_loss: 0.1365 - val_dense_4_loss: 0.0900 - val_dense_2_accuracy: 0.9024 - val_dense_3_accuracy: 0.9639 - val_dense_4_accuracy: 0.9709
# Epoch 27/30
# 180/180 [==============================] - ETA: 0s - loss: 0.7135 - dense_2_loss: 0.4027 - dense_3_loss: 0.1877 - dense_4_loss: 0.1230 - dense_2_accuracy: 0.8791 - dense_3_accuracy: 0.9438 - dense_4_accuracy: 0.9612WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 228ms/step - loss: 0.7135 - dense_2_loss: 0.4027 - dense_3_loss: 0.1877 - dense_4_loss: 0.1230 - dense_2_accuracy: 0.8791 - dense_3_accuracy: 0.9438 - dense_4_accuracy: 0.9612 - val_loss: 0.5635 - val_dense_2_loss: 0.3627 - val_dense_3_loss: 0.1031 - val_dense_4_loss: 0.0977 - val_dense_2_accuracy: 0.9004 - val_dense_3_accuracy: 0.9736 - val_dense_4_accuracy: 0.9694
# Epoch 28/30
# 180/180 [==============================] - ETA: 0s - loss: 0.6983 - dense_2_loss: 0.3872 - dense_3_loss: 0.1831 - dense_4_loss: 0.1280 - dense_2_accuracy: 0.8828 - dense_3_accuracy: 0.9454 - dense_4_accuracy: 0.9600WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 227ms/step - loss: 0.6983 - dense_2_loss: 0.3872 - dense_3_loss: 0.1831 - dense_4_loss: 0.1280 - dense_2_accuracy: 0.8828 - dense_3_accuracy: 0.9454 - dense_4_accuracy: 0.9600 - val_loss: 0.6286 - val_dense_2_loss: 0.3755 - val_dense_3_loss: 0.1590 - val_dense_4_loss: 0.0941 - val_dense_2_accuracy: 0.8982 - val_dense_3_accuracy: 0.9549 - val_dense_4_accuracy: 0.9751
# Epoch 29/30
# 180/180 [==============================] - ETA: 0s - loss: 0.6818 - dense_2_loss: 0.3768 - dense_3_loss: 0.1788 - dense_4_loss: 0.1263 - dense_2_accuracy: 0.8855 - dense_3_accuracy: 0.9448 - dense_4_accuracy: 0.9601WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 0.6818 - dense_2_loss: 0.3768 - dense_3_loss: 0.1788 - dense_4_loss: 0.1263 - dense_2_accuracy: 0.8855 - dense_3_accuracy: 0.9448 - dense_4_accuracy: 0.9601 - val_loss: 0.5654 - val_dense_2_loss: 0.3659 - val_dense_3_loss: 0.1088 - val_dense_4_loss: 0.0907 - val_dense_2_accuracy: 0.9007 - val_dense_3_accuracy: 0.9696 - val_dense_4_accuracy: 0.9731
# Epoch 30/30
# 180/180 [==============================] - ETA: 0s - loss: 0.6646 - dense_2_loss: 0.3660 - dense_3_loss: 0.1763 - dense_4_loss: 0.1223 - dense_2_accuracy: 0.8894 - dense_3_accuracy: 0.9476 - dense_4_accuracy: 0.9615WARNING:tensorflow:Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: loss,dense_2_loss,dense_3_loss,dense_4_loss,dense_2_accuracy,dense_3_accuracy,dense_4_accuracy,val_loss,val_dense_2_loss,val_dense_3_loss,val_dense_4_loss,val_dense_2_accuracy,val_dense_3_accuracy,val_dense_4_accuracy,lr
# 180/180 [==============================] - 41s 226ms/step - loss: 0.6646 - dense_2_loss: 0.3660 - dense_3_loss: 0.1763 - dense_4_loss: 0.1223 - dense_2_accuracy: 0.8894 - dense_3_accuracy: 0.9476 - dense_4_accuracy: 0.9615 - val_loss: 0.5535 - val_dense_2_loss: 0.3595 - val_dense_3_loss: 0.1080 - val_dense_4_loss: 0.0859 - val_dense_2_accuracy: 0.9032 - val_dense_3_accuracy: 0.9676 - val_dense_4_accuracy: 0.9754
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-c9377dac4889> in <module>()
#      61     histories.append(history)
#      62     model.save('bengali_model.h5')
# ---> 63     np.save('history.npy',history)
#      64     # Delete to reduce memory usage
#      65     del x_train
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     551         arr = np.asanyarray(arr)
#     552         format.write_array(fid, arr, allow_pickle=allow_pickle,
# --> 553                            pickle_kwargs=pickle_kwargs)
#     554     finally:
#     555         if own_fid:
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/format.py in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     674         if pickle_kwargs is None:
#     675             pickle_kwargs = {}
# --> 676         pickle.dump(array, fp, protocol=3, **pickle_kwargs)
#     677     elif array.flags.f_contiguous and not array.flags.c_contiguous:
#     678         if isfileobj(fp):
#
# TypeError: can't pickle _thread.RLock objects

# %%
#don't run this cell during prediction
from google.colab import files


files.download('bengali_model.h5')
files.download('history.npy')

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_2_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_2_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_2_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_2_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(1):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %% [markdown]
# ## Prediction

# %%
from google.colab import files
from tensorflow import keras
import cv2

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-40313279-81ce-42c2-93b1-f22e3be5c846" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40313279-81ce-42c2-93b1-f22e3be5c846">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bengali_model.h5 to bengali_model.h5
# User uploaded file "bengali_model.h5" with length 117106408 bytes

# %%
model = keras.models.load_model("bengali_model.h5")

# %%
#upload image
upload = files.upload()
for fn in upload.keys():
  image_name = fn
# Out:
#      <input type="file" id="files-12e1e6c2-4f0f-4c23-8aae-02fadf1c6052" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12e1e6c2-4f0f-4c23-8aae-02fadf1c6052">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download (4).png to download (4).png

# %%
IMG_SIZE = 64
N_CHANNELS = 1
img = cv2.imread(image_name,0)
img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
img = img.reshape(1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
result = model.predict(img)

# %%
print('Result:',result)
# Out:
# Result: [array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 2.7997179e-19, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 4.5390118e-30, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.8750897e-01,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 8.1249100e-01, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6920801e-36,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#       dtype=float32), array([[4.8552783e-38, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00]], dtype=float32), array([[0., 0., 0., 0., 1., 0., 0.]], dtype=float32)]

# %%
import numpy as np
print('Root:',np.argmax(result[0]))
print('Vowel:',np.argmax(result[1]))
print('Consonants:',np.argmax(result[2]))
# Out:
# Root: 122
# Vowel: 1
# Consonants: 4
